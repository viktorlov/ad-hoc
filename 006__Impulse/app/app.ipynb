# %%
import pandas as pd
# читаем исходные данные из файла
FILE_PATH = 'impulse_dataset.xlsx'
df_raw = pd.read_excel(FILE_PATH, None)

# %%
# печатаем для информации список листов книги эксель
sheets = list(df_raw.keys())
for k, v in enumerate(sheets):
    print(k, v)
# Out:
# 0 Основная комната – Зрители
# 1 QA – Зрители
# 2 DA – Зрители
# 3 Маркетинг – зрители
# 4 Дизайн – зрители
# 5 Python – зрители
# 6 Java – Зрители
# 7 Веб – зрители

# %%
from constants import columns
from utils import dataframe_processing, result_grabbing, plotting
for k, v in enumerate(df_raw.keys()):
    current = dataframe_processing(df_raw, k, columns)
    result = result_grabbing(current)
    plotting(result, str(v))
    current.to_excel(str('data/'+v+'__current.xlsx'))
    result.to_excel(str('data/'+v+'__result.xlsx'))
