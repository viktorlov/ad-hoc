# %%
import pandas as pd

# %%
chars = pd.read_csv('StarWarsCharacters.csv')
chars
# Out:
#               name  height mass hair_color   skin_color eye_color birth_year  \
# 0   Luke Skywalker   172.0   77      blond         fair      blue      19BBY
# 1            C-3PO   167.0   75        NaN         gold    yellow     112BBY
# 2            R2-D2    96.0   32        NaN  white, blue       red      33BBY
# 3      Darth Vader   202.0  136       none        white    yellow    41.9BBY
# 4      Leia Organa   150.0   49      brown        light     brown      19BBY
# ..             ...     ...  ...        ...          ...       ...        ...
# 82             Rey     NaN  NaN      brown        light     hazel        NaN
# 83     Poe Dameron     NaN  NaN      brown        light     brown        NaN
# 84             BB8     NaN  NaN       none         none     black        NaN
# 85  Captain Phasma     NaN  NaN        NaN          NaN       NaN        NaN
# 86   Padmé Amidala   165.0   45      brown        light     brown      46BBY
#
#     gender homeworld species
# ...

# %%
plans = pd.read_csv('StarWarsPlanets.csv')
plans
# Out:
#         name  rotation_period  orbital_period  diameter  \
# 0   Alderaan             24.0           364.0   12500.0
# 1   Yavin IV             24.0          4818.0   10200.0
# 2       Hoth             23.0           549.0    7200.0
# 3    Dagobah             23.0           341.0    8900.0
# 4     Bespin             12.0          5110.0  118000.0
# ..       ...              ...             ...       ...
# 56     Shili              NaN             NaN       NaN
# 57     Kalee             23.0           378.0   13850.0
# 58    Umbara              NaN             NaN       NaN
# 59  Tatooine             23.0           304.0   10465.0
# 60     Jakku              NaN             NaN       NaN
#
#                       climate                                 gravity  \
# 0                   temperate                              1 standard
# 1         temperate, tropical                              1 standard
# 2                      frozen                            1.1 standard
# ...

# %%
specs = pd.read_csv('StarWarsSpecies.csv')
specs
# Out:
#               name classification designation  average_height  \
# 0             Hutt      gastropod    sentient           300.0
# 1   Yoda's species         mammal    sentient            66.0
# 2       Trandoshan        reptile    sentient           200.0
# 3     Mon Calamari      amphibian    sentient           160.0
# 4             Ewok         mammal    sentient           100.0
# 5        Sullustan         mammal    sentient           180.0
# 6        Neimodian            NaN    sentient           180.0
# 7           Gungan      amphibian    sentient           190.0
# 8        Toydarian         mammal    sentient           120.0
# 9              Dug         mammal    sentient           100.0
# 10         Twi'lek        mammals    sentient           200.0
# 11          Aleena        reptile    sentient            80.0
# 12      Vulptereen            NaN    sentient           100.0
# 13           Xexto            NaN    sentient           125.0
# ...
